# %%
import warnings
import itertools
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression, LinearRegression, ElasticNet, SGDRegressor

from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from xgboost import XGBClassifier

from sklearn.metrics import confusion_matrix

# %%
df_train = pd.read_csv('../data/raw/Data_Set_Loan_predit/train_data_set.csv')
df_test = pd.read_csv('../data/raw/Data_Set_Loan_predit/test_data_set.csv')
# pd.read_csv('../data/raw/Data_Set_Loan_predit/_data_set.csv')
df_test["Loan_Status"] = "X"
data_preprocess = pd.concat([df_train, df_test]).reset_index()
data_preprocess.drop(['index'], axis=1, inplace=True)
# data_preprocess['Dependents'].fillna(0, inplace=True)

# %%
data_preprocess['Dependents'].fillna(0, inplace=True)
data_preprocess['Credit_History'].fillna(0, inplace=True)
data_preprocess["Married"].fillna("No", inplace=True)
data_preprocess["Gender"].fillna("Male", inplace=True)
data_preprocess["Gender"][720] = "Female" 
data_preprocess["Dependents"] = data_preprocess["Dependents"].apply(lambda x: 3 if x == '3+' else int(x))
# data_preprocess["Dependents"].astype(int, inplace=True)
# print(data_preprocess.isnull().sum())
# data_preprocess.info()

# %%
# X_n, 
emp_self_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 981 entries, 0 to 980
# Data columns (total 15 columns):
# level_0              981 non-null int64
# index                981 non-null int64
# Loan_ID              981 non-null object
# Gender               981 non-null object
# Married              981 non-null object
# Dependents           981 non-null int64
# Education            981 non-null object
# Self_Employed        981 non-null object
# ApplicantIncome      981 non-null int64
# CoapplicantIncome    981 non-null float64
# LoanAmount           981 non-null float64
# Loan_Amount_Term     961 non-null float64
# Credit_History       981 non-null float64
# Property_Area        981 non-null object
# Loan_Status          981 non-null object
# dtypes: float64(4), int64(4), object(7)
# memory usage: 115.0+ KB

# %%
self_data_not = data_preprocess[data_preprocess["Self_Employed"].notnull()]["Self_Employed"].values
self_data_is = self_Emp
emp_self_data = pd.concat([data_preprocess[data_preprocess["Self_Employed"].notnull()], data_preprocess[data_preprocess["Self_Employed"].isnull()]]).reset_index()
# data_preprocess[data_preprocess["Self_Employed"].isnull()]["Self_Employed"] = self_Emp 
emp_self_data['Self_Employed'] = np.concatenate((self_data_not , self_data_is), axis=0)

# %%
self_data_not = emp_self_data[emp_self_data["LoanAmount"].notnull()]["LoanAmount"].values
self_data_is = X_n
emp_self_data = pd.concat([emp_self_data[emp_self_data["LoanAmount"].notnull()], emp_self_data[emp_self_data["LoanAmount"].isnull()]]).reset_index()
# data_preprocess[data_preprocess["Self_Employed"].isnull()]["Self_Employed"] = self_Emp 
emp_self_data['LoanAmount'] = np.concatenate((self_data_not , self_data_is), axis=0)

# %%
np.concatenate((self_data_not , self_data_is), axis=0)
# emp_self_data["Self_Employed"] = 
# self_Emp
# np.concat
emp_self_data.info()
emp_self_data.to_csv('../data/processed/cleaned_ex2.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 981 entries, 0 to 980
# Data columns (total 15 columns):
# level_0              981 non-null int64
# index                981 non-null int64
# Loan_ID              981 non-null object
# Gender               981 non-null object
# Married              981 non-null object
# Dependents           981 non-null int64
# Education            981 non-null object
# Self_Employed        981 non-null object
# ApplicantIncome      981 non-null int64
# CoapplicantIncome    981 non-null float64
# LoanAmount           981 non-null float64
# Loan_Amount_Term     961 non-null float64
# Credit_History       981 non-null float64
# Property_Area        981 non-null object
# Loan_Status          981 non-null object
# dtypes: float64(4), int64(4), object(7)
# memory usage: 115.0+ KB

# %%
emp_self_data
# Out:
#      index   Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0        0  LP001002    Male      No           0      Graduate            No
# 1        1  LP001003    Male     Yes           1      Graduate            No
# 2        2  LP001005    Male     Yes           0      Graduate           Yes
# 3        3  LP001006    Male     Yes           0  Not Graduate            No
# 4        4  LP001008    Male      No           0      Graduate            No
# 5        5  LP001011    Male     Yes           2      Graduate           Yes
# 6        6  LP001013    Male     Yes           0  Not Graduate            No
# 7        7  LP001014    Male     Yes           3      Graduate            No
# 8        8  LP001018    Male     Yes           2      Graduate            No
# 9        9  LP001020    Male     Yes           1      Graduate            No
# 10      10  LP001024    Male     Yes           2      Graduate            No
# ...

# %%
gdr_Data['Self_Employed'].value_counts()
# Out:
# No     807
# Yes    119
# Name: Self_Employed, dtype: int64

# %%
# data_preprocess.
gdr_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 981 entries, 0 to 980
# Data columns (total 9 columns):
# Self_Employed        926 non-null object
# Gender               981 non-null int64
# Married              981 non-null int64
# Dependents           981 non-null int64
# Education            981 non-null int64
# ApplicantIncome      981 non-null int64
# CoapplicantIncome    981 non-null float64
# Credit_History       981 non-null float64
# Property_Area        981 non-null object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 69.1+ KB

# %%
# data_preprocess[data_preprocess["Married"] == "Yes"]
# gdr_Data = data_preprocess[data_preprocess["Self_Employed"].notnull()]
self_Data = data_preprocess[['Self_Employed', 'Gender', 'Married', 'Dependents', 'Education',
        'ApplicantIncome', 'CoapplicantIncome', 'Credit_History', 'Property_Area']]
gdr_Data = self_Data #pd.concat([self_Data[self_Data["Self_Employed"].notnull()], self_Data[self_Data["Self_Employed"].isnull()]])

gdr_Data["Married"] = gdr_Data["Married"].apply(lambda x: 1 if x == 'Yes' else 0)
gdr_Data["Education"] = gdr_Data["Education"].apply(lambda x: 1 if x == 'Graduate' else 0)
# gdr_Data["Self_Employed"]  = gdr_Data["Self_Employed"].apply(lambda x: 1 if x == 'No' else 0)
gdr_Data["Gender"] = gdr_Data["Gender"].apply(lambda x: 1 if x == 'Male' else 0)

# print(trn_gdr_data.shape)
# print(tst_gdr_data.shape)

# data_preprocess[data_preprocess["Self_Employed"].notnull()]
# data_preprocess[mtc]
# data_preprocess[::460]

# %%
# gdr_Data = data_preprocess[data_preprocess["Self_Employed"].notnull()]
test_self = gdr_Data[gdr_Data['Self_Employed'].isnull()]
train_self = gdr_Data[gdr_Data['Self_Employed'].notnull()]

# gdr_Data[gdr_Data["Gender"].isnull()]
# gdr_Data.Gender.value_counts()
# data_preprocess["Gender"].value_counts()

# %%
# data_preprocess[data_preprocess["Self_Employed"].notnull()]["Gender"].isnull()

# %%
self_Emp

# %%
# data.

# %%
trn_data = pd.get_dummies(df_downsampled.loc[:,"Gender":])
tst_data = pd.get_dummies(test_self.loc[:,"Gender":])

# trn_gdr_data = data[:902]
# tst_gdr_data =  data[902:]

# %%
# data["Self_Employed"].isnull()
trn_data.columns, tst_data.columns
# Out:
# (Index(['Gender', 'Married', 'Dependents', 'Education', 'ApplicantIncome',
#         'CoapplicantIncome', 'Credit_History', 'Property_Area_Rural',
#         'Property_Area_Semiurban', 'Property_Area_Urban'],
#        dtype='object'),
#  Index(['Gender', 'Married', 'Dependents', 'Education', 'ApplicantIncome',
#         'CoapplicantIncome', 'Credit_History', 'Property_Area_Rural',
#         'Property_Area_Semiurban', 'Property_Area_Urban'],
#        dtype='object'))

# %%
X_train, X_test, y_train, y_test = train_test_split(trn_data.values, df_downsampled["Self_Employed"].values,  test_size=0.3, random_state= 24)

# %%
X_train, X_test, y_train, y_test = train_test_split(trn_data.values, df_downsampled["Self_Employed"].values,  test_size=0.3, random_state= 24)
xgbRer = XGBClassifier(learning_rate=0.2, n_estimators=100, reg_lambda=0.5, random_state=24, booster="gbtree")
xgbRer.fit(X_train, y_train)
print(xgbRer.score(X_train, y_train))
xgbRer.score(X_test, y_test)
# Out:
# 0.9574132492113565
# 0.8644688644688645

# %%
confusion_matrix(y_test, xgbRer.predict(X_test))
# xgbRer.predict(tst_gdr_data.values)
# Out:
# array([[230,  12],
#        [ 25,   6]], dtype=int64)

# %%
lr = RandomForestClassifier()
lr = GridSearchCV(lr,{},cv=5)
lr.fit(X_train, y_train)
lr.score(X_test, y_test)
# Out:
# 0.8864468864468864

# %%
self_Emp = xgbRer.predict(tst_data.values)

# %%
gdr_Data["Gender"].value_counts()
# Out:
# Male      731
# Female    171
# Name: Gender, dtype: int64

# %%
## Down sampling
from sklearn.utils import resample
# Separate majority and minority classes
# df = train_self
# df_majority = df[df.Gender==1]
# df_minority = df[df.Gender==0]

df = train_self
df_majority = df[df.Self_Employed=="No"]
df_minority = df[df.Self_Employed=="Yes"]
 
# Downsample majority class
df_majority_downsampled = resample(df_majority, 
                                 replace=False,    # sample without replacement
                                 n_samples=49,     # to match minority class
                                 random_state=123) # reproducible results
 
# Combine minority class with downsampled majority class
df_downsampled = pd.concat([df_majority_downsampled, df_minority])
 
# Display new class counts
df_downsampled.Self_Employed.value_counts()
# 1    49
# 0    49
# Name: balance, dtype: int64
# Out:
# Yes    119
# No      49
# Name: Self_Employed, dtype: int64

# %%
## Upsampling

# # Separate majority and minority classes
# df_majority = df[df.balance==0]
# df_minority = df[df.balance==1]
 
# # Upsample minority class
# df_minority_upsampled = resample(df_minority, 
#                                  replace=True,     # sample with replacement
#                                  n_samples=576,    # to match majority class
#                                  random_state=123) # reproducible results
 
# # Combine majority class with upsampled minority class
# df_upsampled = pd.concat([df_majority, df_minority_upsampled])
 
# # Display new class counts
# df_upsampled.balance.value_counts()
# # 1    576
# # 0    576
# # Name: balance, dtype: int64


from sklearn.utils import resample
# Separate majority and minority classes
df = train_self
df_majority = df[df.Self_Employed=="No"]
df_minority = df[df.Self_Employed=="Yes"]
 
# Downsample majority class
df_minority_upsampled = resample(df_minority, 
                                 replace=True,    # sample without replacement
                                 n_samples=100,     # to match minority class
                                 random_state=123) # reproducible results
 
# Combine minority class with downsampled majority class
df_downsampled = pd.concat([df_majority, df_minority_upsampled])
 
# Display new class counts
df_downsampled.Self_Employed.value_counts()
# 1    49
# 0    49
# Name: balance, dtype: int64
# Out:
# No     807
# Yes    100
# Name: Self_Employed, dtype: int64

# %%
train_self['Self_Employed'].value_counts()
# Out:
# No     807
# Yes    119
# Name: Self_Employed, dtype: int64

# %%
train_self["Self_Employed"].value_counts()
# Out:
# No     807
# Yes    119
# Name: Self_Employed, dtype: int64

# %%
df_train.shape
# Out:
# (614, 13)

# %%
xgbRer = XGBClassifier(learning_rate=0.1, n_estimators=100, reg_lambda=0.1, random_state=84, booster="gbtree",
 max_depth=5,
 min_child_weight=1,
 gamma=0,
 subsample=0.8,
 colsample_bytree=0.8,
 nthread=4,
 scale_pos_weight=1,
 seed=27)

params=xgbRer.get_xgb_params()
xgb_param=dict([(key,[params[key]]) for key in params])
# boost = xgb.sklearn.XGBClassifier()
cvresult = GridSearchCV(xgbRer,xgb_param,cv=5)
cvresult.fit(X_train, y_train)
alg=cvresult.best_estimator_
# xgbRer.fit(X_train, y_train)
cvresult.score(X_test, y_test)
# Out:
# 0.8087248322147651

# %%
help(xgbRer)
# Out:
# Help on XGBClassifier in module xgboost.sklearn object:
#
# class XGBClassifier(XGBModel, sklearn.base.ClassifierMixin)
#  |  Implementation of the scikit-learn API for XGBoost classification.
#  |
#  |  Parameters
#  |  ----------
#  |  max_depth : int
#  |      Maximum tree depth for base learners.
#  |  learning_rate : float
#  |      Boosting learning rate (xgb's "eta")
#  |  n_estimators : int
#  |      Number of boosted trees to fit.
#  |  silent : boolean
#  |      Whether to print messages while running boosting.
#  |  objective : string or callable
#  |      Specify the learning task and the corresponding learning objective or
#  |      a custom objective function to be used (see note below).
#  |  booster: string
#  |      Specify which booster to use: gbtree, gblinear or dart.
#  |  nthread : int
#  |      Number of parallel threads used to run xgboost.  (Deprecated, please use ``n_jobs``)
#  |  n_jobs : int
# ...

# %%
xgbRer.coef_
# Out:
# [0.0356395,
#  1.40578e-05,
#  2.42022e-05,
#  0.0407344,
#  0.00673205,
#  0.0483008,
#  0.036328,
#  0.0192632,
#  0.040809,
#  0.0108961,
#  0.021727,
#  0.0181601,
#  0.0239435]

# %%
trn_gdr_data[]
# Out:
#      Dependents  ApplicantIncome  CoapplicantIncome  Credit_History  \
# 0             0             5849                0.0             1.0
# 1             1             4583             1508.0             1.0
# 2             0             3000                0.0             1.0
# 3             0             2583             2358.0             1.0
# 4             0             6000                0.0             1.0
# 5             2             5417             4196.0             1.0
# 6             0             2333             1516.0             1.0
# 7             3             3036             2504.0             0.0
# 8             2             4006             1526.0             1.0
# 9             1            12841            10968.0             1.0
# 10            2             3200              700.0             1.0
# 12            2             3073             8106.0             1.0
# 13            0             1853             2840.0             1.0
# ...

# %%
import xgboost as xgb
import sklearn
import numpy as np
from sklearn.model_selection import GridSearchCV

def modelfit(alg, train_data_features, train_labels,useTrainCV=True, cv_folds=5):

    if useTrainCV:
        params=alg.get_xgb_params()
        xgb_param=dict([(key,[params[key]]) for key in params])

        boost = xgb.sklearn.XGBClassifier()
        cvresult = GridSearchCV(boost,xgb_param,cv=cv_folds)
        cvresult.fit(X,y)
        alg=cvresult.best_estimator_


    #Fit the algorithm on the data
    alg.fit(train_data_features, train_labels)

    #Predict training set:
    dtrain_predictions = alg.predict(train_data_features)
    dtrain_predprob = alg.predict_proba(train_data_features)[:,1]

    #Print model report:
    print("\nModel Report")
    print("Accuracy : %.4g" % sklearn.metrics.accuracy_score(train_labels, dtrain_predictions))

xgb1 = xgb.sklearn.XGBClassifier(
 learning_rate =0.1,
 n_estimators=50,
 max_depth=5,
 min_child_weight=1,
 gamma=0,
 subsample=0.8,
 colsample_bytree=0.8,
 objective='multi:softmax',
 nthread=4,
 scale_pos_weight=1,
 seed=27)    


X=np.random.normal(size=(200,30))
y=np.random.randint(0,5,200)

modelfit(xgb1, X_train, y_train)
# Out:
# c:\users\lokesh\appdata\local\programs\python\python36\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# <ipython-input-268-07f93c68b676> in <module>
#      44 y=np.random.randint(0,5,200)
#      45
# ---> 46 modelfit(xgb1, X_train, y_train)
#
# <ipython-input-268-07f93c68b676> in modelfit(alg, train_data_features, train_labels, useTrainCV, cv_folds)
#      17
#      18     #Fit the algorithm on the data
# ---> 19     alg.fit(train_data_features, train_labels)
#      20
#      21     #Predict training set:
#
# ...

# %%
y_train.shape
# Out:
# (298, 13)

# %%
help(df)
# Out:
# Help on DataFrame in module pandas.core.frame object:
#
# class DataFrame(pandas.core.generic.NDFrame)
#  |  Two-dimensional size-mutable, potentially heterogeneous tabular data
#  |  structure with labeled axes (rows and columns). Arithmetic operations
#  |  align on both row and column labels. Can be thought of as a dict-like
#  |  container for Series objects. The primary pandas data structure.
#  |
#  |  Parameters
#  |  ----------
#  |  data : numpy ndarray (structured or homogeneous), dict, or DataFrame
#  |      Dict can contain Series, arrays, constants, or list-like objects
#  |
#  |      .. versionchanged :: 0.23.0
#  |         If data is a dict, argument order is maintained for Python 3.6
#  |         and later.
#  |
#  |  index : Index or array-like
#  |      Index to use for resulting frame. Will default to RangeIndex if
#  |      no indexing information part of input data and no index provided
#  |  columns : Index or array-like
# ...

# %%
emp_self_data.columns
# Out:
# Index(['index', 'Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df_train.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
emp_self_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 981 entries, 0 to 980
# Data columns (total 15 columns):
# level_0              981 non-null int64
# index                981 non-null int64
# Loan_ID              981 non-null object
# Gender               981 non-null object
# Married              981 non-null object
# Dependents           981 non-null int64
# Education            981 non-null object
# Self_Employed        981 non-null object
# ApplicantIncome      981 non-null int64
# CoapplicantIncome    981 non-null float64
# LoanAmount           981 non-null float64
# Loan_Amount_Term     961 non-null float64
# Credit_History       981 non-null float64
# Property_Area        981 non-null object
# Loan_Status          981 non-null object
# dtypes: float64(4), int64(4), object(7)
# memory usage: 115.0+ KB

# %%
loan_data = emp_self_data[['Loan_Amount_Term', 'LoanAmount', 'Gender', 'Married', 'Dependents', 'Education',
       'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome',
        'Credit_History', 'Property_Area']]
loan_data["Married"] = loan_data["Married"].apply(lambda x: 1 if x == 'Yes' else 0)
loan_data["Education"] = loan_data["Education"].apply(lambda x: 1 if x == 'Graduate' else 0)
loan_data["Self_Employed"]  = loan_data["Self_Employed"].apply(lambda x: 1 if x == 'Yes' else 0)
loan_data["Gender"] = loan_data["Gender"].apply(lambda x: 1 if x == 'Male' else 0)
loan_data2 = pd.get_dummies(loan_data)
test_data = loan_data2[loan_data2['Loan_Amount_Term'].isnull()]
train_data = loan_data2[loan_data2['Loan_Amount_Term'].notnull()]

# %%
X_train, X_test, y_train, y_test = train_test_split(train_data.loc[:, "LoanAmount":"LoanAmount"].values, train_data["Loan_Amount_Term"].values,  test_size=0.22, random_state= 42)
xgbRer = XGBRegressor(learning_rate=1.2, n_estimators=100, random_state=42, booster="gblinear")
xgbRer.fit(X_train, y_train)
print(xgbRer.score(X_train, y_train))
xgbRer.score(X_test, y_test)
# Out:
# 0.004944050691450541
# -0.0045199267484137265

# %%
lrr = RandomForestRegressor(n_estimators=100, criterion="mse", min_samples_split=3, n_jobs=1000)
lrr.fit(X_train, y_train)
print(lrr.score(X_train, y_train))
lrr.score(X_test, y_test)
# Out:
# 0.2947086970662496
# -0.18157051944699987

# %%
X_n = lrr.predict(test_data.loc[:,"Gender":].values)
X_n
# Out:
# array([134.14704906, 101.23598413, 130.33046825,  98.91331999,
#        257.46306385, 156.38772835, 117.82675541, 128.50079762,
#         65.00773016, 401.63913781,  54.00517857, 118.21421001,
#         59.53561147, 141.11048665, 216.16203175,  88.80087338,
#        119.73313997, 137.87457937, 170.00576732, 126.0756627 ,
#        125.7969246 , 159.1637619 , 108.89948016, 191.10635354,
#        197.42634127, 316.93204365, 112.47619156])

# %%
lrr = SGDRegressor(penalty="l2", alpha=0.1, max_iter=5000, shuffle=True, learning_rate='adaptive', n_iter=0.21)
lrr.fit(X_train, y_train)
print(lrr.score(X_train, y_train))
lrr.score(X_test, y_test)
# Out:
# -28.185047678973344
# -25.75721380033088

# %%
help(lrr)
# Out:
# Help on RandomForestRegressor in module sklearn.ensemble.forest object:
#
# class RandomForestRegressor(ForestRegressor)
#  |  A random forest regressor.
#  |
#  |  A random forest is a meta estimator that fits a number of classifying
#  |  decision trees on various sub-samples of the dataset and uses averaging
#  |  to improve the predictive accuracy and control over-fitting.
#  |  The sub-sample size is always the same as the original
#  |  input sample size but the samples are drawn with replacement if
#  |  `bootstrap=True` (default).
#  |
#  |  Read more in the :ref:`User Guide <forest>`.
#  |
#  |  Parameters
#  |  ----------
#  |  n_estimators : integer, optional (default=10)
#  |      The number of trees in the forest.
#  |
#  |      .. versionchanged:: 0.20
#  |         The default value of ``n_estimators`` will change from 10 in
#  |         version 0.20 to 100 in version 0.22.
#  |
#  |  criterion : string, optional (default="mse")
# ...

# %%
train_data.loc[:, "LoanAmount":"LoanAmount"]
# Out:
#      LoanAmount
# 0    128.000000
# 1     66.000000
# 2    120.000000
# 3    141.000000
# 4    267.000000
# 5     95.000000
# 6    158.000000
# 7    168.000000
# 8    349.000000
# 9     70.000000
# 10   200.000000
# 11   114.000000
# 12    17.000000
# 13   125.000000
# 14   100.000000
# 15    76.000000
# 16   133.000000
# 17   104.000000
# 18   315.000000
# 19   116.000000
# 20   112.000000
# 21   191.000000
# 22   122.000000
# 23   110.000000
# 24    35.000000
# 25    74.000000
# 26   106.000000
# 27   114.000000
# 28   320.000000
# 30   144.000000
# ..          ...
# 951  125.000000
# 952   40.000000
# 953  122.000000
# 954  134.147049
# 955  101.235984
# 956  130.330468
# 957   98.913320
# 958  257.463064
# 959  156.387728
# 960  117.826755
# 961  128.500798
# 962   65.007730
# 963  401.639138
# 964   54.005179
# 965  118.214210
# 966   59.535611
# 967  141.110487
# 968  216.162032
# 969   88.800873
# 970  119.733140
# 971  137.874579
# 972  170.005767
# 973  126.075663
# ...

# %%
lrr.feature_importances_
# Out:
# array([0.01274068, 0.02846343, 0.04715743, 0.00665011, 0.01499968,
#        0.61884752, 0.20291375, 0.0220833 , 0.01272824, 0.00822897,
#        0.01285325, 0.01233364])

# %%
# train_data['LoanAmount']

# %%
# emp_self_data["Loan_Amount_Term"].value_counts()

# %%
# emp_self_data[emp_self_data["Loan_Amount_Term"] == 480]
